# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulrhman369/labs/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import the required libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules
# %matplotlib inline

# %%
#Download the data set
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip

#Extract the files
import zipfile
with zipfile.ZipFile('online+retail.zip', 'r') as datafilezip:
  print(datafilezip.infolist())
  datafilezip.extract("Online Retail.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# --2024-10-28 22:48:07--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip.2’
#
# online+retail.zip.2     [    <=>             ]  22.62M  5.43MB/s    in 7.7s
#
# 2024-10-28 22:48:15 (2.96 MB/s) - ‘online+retail.zip.2’ saved [23715478]
#
# [<ZipInfo filename='Online Retail.xlsx' filemode='-rwx------' file_size=23715344>]

# %%
#Load the data set
df = pd.read_excel('Online Retail.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
#Extract the first five entries
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#Access the list of column names
colnames = df.columns
colnames
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#Extract the list of countries
df.Country.unique()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#Length of the dataframe before cleaning
len(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 541909

# %%
#Identify entries with "C" in the invoice number
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df[df['InvoiceNo'].str.contains('C')].head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
#Identify entries with "A" in the invoice number
df[df['InvoiceNo'].str.contains('A')]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
#Exclude unnecessary entries from the dataframe
df = df[~df['InvoiceNo'].str.contains('C|A')]
len(df) # this now prints 532618
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 532618

# %%
#Grouping data for specific countries
subset_df = df[df['Country'].isin(['Denmark', 'Germany', 'Italy'])]
subset_df = subset_df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum()
subset_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# InvoiceNo  Description
# 536527     3 HOOK HANGER MAGIC GARDEN             12
#            5 HOOK HANGER MAGIC TOADSTOOL          12
#            5 HOOK HANGER RED MAGIC TOADSTOOL      12
#            ASSORTED COLOUR LIZARD SUCTION HOOK    24
#            CHILDREN'S CIRCUS PARADE MUG           12
# Name: Quantity, dtype: int64

# %%
#Unpack the data
subset_df = subset_df.unstack().reset_index()
subset_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Description InvoiceNo   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# 0              536527                             NaN                 NaN
# 1              536840                             NaN                 NaN
# 2              536861                             NaN                 NaN
# 3              536967                             NaN                 NaN
# 4              536983                             NaN                 NaN
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# 0                                     NaN                       NaN
# 1                                     NaN                       NaN
# 2                                     NaN                       NaN
# 3                                     NaN                       NaN
# 4                                     NaN                       NaN
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                                         NaN                      NaN
# 4                                         NaN                      NaN
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
#
# Description  12 EGG HOUSE PAINTED WOOD  ...  YULETIDE IMAGES GIFT WRAP SET  \
# 0                                  NaN  ...                            NaN
# 1                                  NaN  ...                            NaN
# 2                                  NaN  ...                            NaN
# 3                                  NaN  ...                            NaN
# 4                                  NaN  ...                            NaN
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER   \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# 0                                          NaN                          NaN
# 1                                          NaN                          NaN
# 2                                          NaN                          NaN
# 3                                          NaN                          NaN
# 4                                          NaN                          NaN
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
# [5 rows x 1788 columns]

# %%
#Replace the NaN values and make the invoice number the index
subset_df = subset_df.fillna(0)
subset_df = subset_df.set_index('InvoiceNo')
subset_df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                  0.0                 0.0
# 536840                                  0.0                 0.0
# 536861                                  0.0                 0.0
# 536967                                  0.0                 0.0
# 536983                                  0.0                 0.0
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                                0.0                       0.0
# 536840                                0.0                       0.0
# 536861                                0.0                       0.0
# 536967                                0.0                       0.0
# 536983                                0.0                       0.0
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536527                                    0.0                      0.0
# 536840                                    0.0                      0.0
# 536861                                    0.0                      0.0
# 536967                                    0.0                      0.0
# 536983                                    0.0                      0.0
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 IVORY ROSE PEG PLACE SETTINGS  ...  \
# InvoiceNo                                                                 ...
# 536527                             0.0                               0.0  ...
# 536840                             0.0                               0.0  ...
# 536861                             0.0                               0.0  ...
# 536967                             0.0                               0.0  ...
# 536983                             0.0                               0.0  ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                 0.0                         0.0
# 536840                                 0.0                         0.0
# 536861                                 0.0                         0.0
# 536967                                 0.0                         0.0
# 536983                                 0.0                         0.0
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                              0.0                 0.0
# 536840                              0.0                 0.0
# 536861                              0.0                 0.0
# 536967                              0.0                 0.0
# 536983                              0.0                 0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                             0.0                                0.0
# 536840                             0.0                                0.0
# 536861                             0.0                                0.0
# 536967                             0.0                                0.0
# 536983                             0.0                                0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                               0.0                             0.0
# 536840                               0.0                             0.0
# 536861                               0.0                             0.0
# 536967                               0.0                             0.0
# 536983                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                   0.0                               0.0
# 536840                                   0.0                               0.0
# 536861                                   0.0                               0.0
# 536967                                   0.0                               0.0
# 536983                                   0.0                               0.0
#
# [5 rows x 1787 columns]

# %%
#View POSTAGE column
subset_df.head()['POSTAGE']
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# InvoiceNo
# 536527    1.0
# 536840    1.0
# 536861    3.0
# 536967    1.0
# 536983    1.0
# Name: POSTAGE, dtype: float64

# %%
#Remove POSTAGE entries
subset_df = subset_df.drop("POSTAGE", axis=1)

# %%
#Encode the data
def hot_encode(x):
    if(x<= 0):
        return False
    else:
        return True

subset_df = subset_df.applymap(hot_encode)
subset_df.head()
# Out:
# /tmp/ipykernel_10039/1448825104.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   subset_df = subset_df.applymap(hot_encode)
# Description   50'S CHRISTMAS GIFT BAG LARGE   DOLLY GIRL BEAKER  \
# InvoiceNo
# 536527                                False               False
# 536840                                False               False
# 536861                                False               False
# 536967                                False               False
# 536983                                False               False
#
# Description   I LOVE LONDON MINI BACKPACK   RED SPOT GIFT BAG LARGE  \
# InvoiceNo
# 536527                              False                     False
# 536840                              False                     False
# 536861                              False                     False
# 536967                              False                     False
# 536983                              False                     False
#
# Description   SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  \
# InvoiceNo
# 536527                                  False                    False
# 536840                                  False                    False
# 536861                                  False                    False
# 536967                                  False                    False
# 536983                                  False                    False
#
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                        False                       False
# 536840                        False                       False
# 536861                        False                       False
# 536967                        False                       False
# 536983                        False                       False
#
# Description  12 EGG HOUSE PAINTED WOOD  12 IVORY ROSE PEG PLACE SETTINGS  ...  \
# InvoiceNo                                                                 ...
# 536527                           False                             False  ...
# 536840                           False                             False  ...
# 536861                           False                             False  ...
# 536967                           False                             False  ...
# 536983                           False                             False  ...
#
# Description  YULETIDE IMAGES GIFT WRAP SET  ZINC  HEART T-LIGHT HOLDER  \
# InvoiceNo
# 536527                               False                       False
# 536840                               False                       False
# 536861                               False                       False
# 536967                               False                       False
# 536983                               False                       False
#
# Description  ZINC  STAR T-LIGHT HOLDER   ZINC BOX SIGN HOME  \
# InvoiceNo
# 536527                            False               False
# 536840                            False               False
# 536861                            False               False
# 536967                            False               False
# 536983                            False               False
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# InvoiceNo
# 536527                           False                              False
# 536840                           False                              False
# 536861                           False                              False
# 536967                           False                              False
# 536983                           False                              False
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536527                             False                           False
# 536840                             False                           False
# 536861                             False                           False
# 536967                             False                           False
# 536983                             False                           False
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                 False                             False
# 536840                                 False                             False
# 536861                                 False                             False
# 536967                                 False                             False
# 536983                                 False                             False
#
# [5 rows x 1786 columns]

# %%
#Apply the Apriori algorithm
frq_items = apriori(subset_df, min_support=0.05, use_colnames=True)
frq_items.sort_values(['support'], ascending=[False])
# Out:
#      support                                           itemsets
# 37  0.237817              (ROUND SNACK BOXES SET OF4 WOODLAND )
# 36  0.150097               (ROUND SNACK BOXES SET OF 4 FRUITS )
# 26  0.134503                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 33  0.132554                         (REGENCY CAKESTAND 3 TIER)
# 23  0.124756                   (PLASTERS IN TIN CIRCUS PARADE )
# 56  0.122807  (ROUND SNACK BOXES SET OF4 WOODLAND , ROUND SN...
# 47  0.118908                           (WOODLAND CHARLOTTE BAG)
# 45  0.109162                              (SPACEBOY LUNCH BOX )
# 24  0.103314                         (PLASTERS IN TIN SPACEBOY)
# 14  0.097466                       (JUMBO BAG WOODLAND ANIMALS)
# 10  0.097466                           (JAM MAKING SET PRINTED)
# 0   0.091618                           (6 RIBBONS RUSTIC CHARM)
# 32  0.089669                    (RED TOADSTOOL LED NIGHT LIGHT)
# 22  0.079922                  (PACK OF 72 RETROSPOT CAKE CASES)
# 16  0.077973                               (LUNCH BAG WOODLAND)
# 46  0.074074                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 13  0.072125                          (JUMBO BAG RED RETROSPOT)
# 54  0.072125  (PLASTERS IN TIN WOODLAND ANIMALS, ROUND SNACK...
# 50  0.072125  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
# 25  0.072125                        (PLASTERS IN TIN STRONGMAN)
# 1   0.072125                        (ALARM CLOCK BAKELIKE PINK)
# 7   0.072125                                (GUMBALL COAT RACK)
# 38  0.070175                (SET OF 3 CAKE TINS PANTRY DESIGN )
# 57  0.068226  (SPACEBOY LUNCH BOX , ROUND SNACK BOXES SET OF...
# 31  0.068226                         (RED RETROSPOT MINI CASES)
# 29  0.068226                      (RED RETROSPOT CHARLOTTE BAG)
# 39  0.066277                       (SET OF 3 REGENCY CAKE TINS)
# 35  0.064327                 (RETROSPOT TEA SET CERAMIC 11 PC )
# 52  0.062378  (PLASTERS IN TIN CIRCUS PARADE , ROUND SNACK B...
# 30  0.062378                                (RED RETROSPOT CUP)
# 48  0.062378                 (WOODLAND PARTY BAG + STICKER SET)
# 15  0.062378                           (LUNCH BAG APPLE DESIGN)
# 58  0.060429  (WOODLAND CHARLOTTE BAG, ROUND SNACK BOXES SET...
# 55  0.058480  (WOODLAND CHARLOTTE BAG, RED RETROSPOT CHARLOT...
# 17  0.058480                (LUNCH BOX WITH CUTLERY RETROSPOT )
# 19  0.058480                              (MINT KITCHEN SCALES)
# 3   0.058480                      (CHARLOTTE BAG APPLES DESIGN)
# 6   0.058480                       (FAWN BLUE HOT WATER BOTTLE)
# 8   0.056530                             (IVORY KITCHEN SCALES)
# 9   0.056530                            (JAM JAR WITH PINK LID)
# 34  0.056530                (RETROSPOT PARTY BAG + STICKER SET)
# 11  0.056530                         (JAM MAKING SET WITH JARS)
# 21  0.054581                    (PACK OF 20 NAPKINS RED APPLES)
# 53  0.054581  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 5   0.054581                         (COFFEE MUG APPLES DESIGN)
# 27  0.054581                               (RABBIT NIGHT LIGHT)
# 20  0.054581                 (PACK OF 20 NAPKINS PANTRY DESIGN)
# 12  0.054581                                 (JUMBO BAG APPLES)
# 28  0.054581                               (RED KITCHEN SCALES)
# 40  0.052632              (SET OF 60 PANTRY DESIGN CAKE CASES )
# 49  0.052632  (PLASTERS IN TIN STRONGMAN, PLASTERS IN TIN CI...
# 44  0.052632                    (SKULL LUNCH BOX WITH CUTLERY )
# 43  0.052632                    (SET/6 RED SPOTTY PAPER PLATES)
# 41  0.052632              (SET/20 RED RETROSPOT PAPER NAPKINS )
# 2   0.050682                    (BAKING SET 9 PIECE RETROSPOT )
# 18  0.050682                        (MEMO BOARD COTTAGE DESIGN)
# 4   0.050682                      (CHILDRENS CUTLERY SPACEBOY )
# 42  0.050682                      (SET/6 RED SPOTTY PAPER CUPS)
# 51  0.050682  (PLASTERS IN TIN CIRCUS PARADE , ROUND SNACK B...

# %%
rules=association_rules(frq_items, metric='lift', min_threshold=1)
rules.sort_values(['lift'], ascending=[False])
# Out:
#                               antecedents  \
# 12               (WOODLAND CHARLOTTE BAG)
# 13          (RED RETROSPOT CHARLOTTE BAG)
# 0             (PLASTERS IN TIN STRONGMAN)
# 1        (PLASTERS IN TIN CIRCUS PARADE )
# 2      (PLASTERS IN TIN WOODLAND ANIMALS)
# 3        (PLASTERS IN TIN CIRCUS PARADE )
# 9      (PLASTERS IN TIN WOODLAND ANIMALS)
# 8              (PLASTERS IN TIN SPACEBOY)
# 15   (ROUND SNACK BOXES SET OF 4 FRUITS )
# 14  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 4        (PLASTERS IN TIN CIRCUS PARADE )
# 5    (ROUND SNACK BOXES SET OF 4 FRUITS )
# 16                  (SPACEBOY LUNCH BOX )
# 17  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 10     (PLASTERS IN TIN WOODLAND ANIMALS)
# 11  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 18               (WOODLAND CHARLOTTE BAG)
# 19  (ROUND SNACK BOXES SET OF4 WOODLAND )
# 6        (PLASTERS IN TIN CIRCUS PARADE )
# 7   (ROUND SNACK BOXES SET OF4 WOODLAND )
#
#                               consequents  antecedent support  \
# 12          (RED RETROSPOT CHARLOTTE BAG)            0.118908
# 13               (WOODLAND CHARLOTTE BAG)            0.068226
# 0        (PLASTERS IN TIN CIRCUS PARADE )            0.072125
# 1             (PLASTERS IN TIN STRONGMAN)            0.124756
# 2        (PLASTERS IN TIN CIRCUS PARADE )            0.134503
# 3      (PLASTERS IN TIN WOODLAND ANIMALS)            0.124756
# 9              (PLASTERS IN TIN SPACEBOY)            0.134503
# 8      (PLASTERS IN TIN WOODLAND ANIMALS)            0.103314
# 15  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.150097
# 14   (ROUND SNACK BOXES SET OF 4 FRUITS )            0.237817
# 4    (ROUND SNACK BOXES SET OF 4 FRUITS )            0.124756
# 5        (PLASTERS IN TIN CIRCUS PARADE )            0.150097
# 16  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.109162
# 17                  (SPACEBOY LUNCH BOX )            0.237817
# 10  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.134503
# 11     (PLASTERS IN TIN WOODLAND ANIMALS)            0.237817
# 18  (ROUND SNACK BOXES SET OF4 WOODLAND )            0.118908
# 19               (WOODLAND CHARLOTTE BAG)            0.237817
# 6   (ROUND SNACK BOXES SET OF4 WOODLAND )            0.124756
# 7        (PLASTERS IN TIN CIRCUS PARADE )            0.237817
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 12            0.068226  0.058480    0.491803  7.208431  0.050367    1.833491
# 13            0.118908  0.058480    0.857143  7.208431  0.050367    6.167641
# 0             0.124756  0.052632    0.729730  5.849240  0.043634    3.238402
# 1             0.072125  0.052632    0.421875  5.849240  0.043634    1.604973
# 2             0.124756  0.072125    0.536232  4.298234  0.055345    1.887244
# 3             0.134503  0.072125    0.578125  4.298234  0.055345    2.051549
# 9             0.103314  0.054581    0.405797  3.927810  0.040685    1.509057
# 8             0.134503  0.054581    0.528302  3.927810  0.040685    1.834854
# 15            0.237817  0.122807    0.818182  3.440387  0.087111    4.192008
# 14            0.150097  0.122807    0.516393  3.440387  0.087111    1.757426
# 4             0.150097  0.050682    0.406250  2.706575  0.031957    1.431415
# 5             0.124756  0.050682    0.337662  2.706575  0.031957    1.321446
# 16            0.237817  0.068226    0.625000  2.628074  0.042266    2.032489
# 17            0.109162  0.068226    0.286885  2.628074  0.042266    1.249221
# 10            0.237817  0.072125    0.536232  2.254811  0.040138    1.643458
# 11            0.134503  0.072125    0.303279  2.254811  0.040138    1.242243
# 18            0.237817  0.060429    0.508197  2.136926  0.032150    1.549773
# 19            0.118908  0.060429    0.254098  2.136926  0.032150    1.181244
# 6             0.237817  0.062378    0.500000  2.102459  0.032709    1.524366
# 7             0.124756  0.062378    0.262295  2.102459  0.032709    1.186441
#
#     zhangs_metric
# 12       0.977507
# 13       0.924338
# 0        0.893480
# 1        0.947208
# 2        0.886596
# 3        0.876723
# 9        0.861245
# 8        0.831289
# 15       0.834608
# 14       0.930662
# 4        0.720404
# 5        0.741884
# 16       0.695405
# 17       0.812788
# 10       0.642988
# 11       0.730144
# 18       0.603840
# 19       0.698045
# 6        0.599109
# 7        0.687980

# %%
#Random sampling of association rules for comparison of confidence and lift values
rules_random=rules.sample(10, random_state = 42)
rules_lift = rules_random[['lift']].to_numpy()
rules_lift = (rules_lift/rules_lift.max()).transpose()[0]
rules_conf = rules_random[['confidence']].to_numpy()
rules_conf = (rules_conf/rules_conf.max()).transpose()[0]
width = 0.40
plt.figure(figsize=(12, 6), dpi=200)

# plot data in grouped manner of bar type
plt.bar(np.arange(len(rules_random))-0.2,rules_lift, width, color='black')
plt.bar(np.arange(len(rules_random))+0.2,rules_conf, width, hatch='//', edgecolor='black', facecolor='white')
plt.xlabel('Instance index')
plt.ylabel('Normalized metric value')
plt.legend(['lift','confidence'])
plt.xticks(range(0,10));
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/IPython/core/pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
